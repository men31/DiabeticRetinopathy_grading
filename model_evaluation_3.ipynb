# %% [markdown]
# # Evaluation notebook 3
# ## proposed to observe the training history of each model

# %% [markdown]
# ## Contents:
# - Logging observation

# %%
import os, sys

import torch
import tqdm

import pandas as pd
import matplotlib.pyplot as plt
from tbparse import SummaryReader
import numpy as np
import seaborn as sns

from utils.evaluation import *

# %% [markdown]
# ## Logging observation

# %%
logs_stock = Call_Logs(r'D:\Aj_Aof_Work\OCT_Disease\Grading\Training_result_WCEloss')

# %%
logs_stock.logs_list
# Out:
# {0: 'densenet161_BalanceData_Imsampler_WCEloss_v1',
#  1: 'densenet161_BalanceData_Imsampler_WCEloss_v2',
#  2: 'densenet161_BalanceData_Imsampler_WCEloss_v3',
#  3: 'swin_s_BalanceData_Imsampler_WCEloss_v1',
#  4: 'swin_s_BalanceData_Imsampler_WCEloss_v2',
#  5: 'swin_s_BalanceData_Imsampler_WCEloss_v3'}

# %%
logs_stock.plot_logs(keyword=['loss', 'f1', 'acc'], num_col=3)

# %%
select_idx = [key for key, val in logs_stock.logs_list.items() if 'densenet' in val]
print(select_idx)
logs_stock.plot_logs_scalar(select_idx, keyword=['val_loss', 'train_loss'])
# Out:
# [0, 1, 2]

# %%
select_idx = [key for key, val in logs_stock.logs_list.items() if 'swin' in val]
print(select_idx)
logs_stock.plot_logs_scalar(select_idx, keyword=['val_loss', 'train_loss'])
# Out:
# [3, 4, 5]
